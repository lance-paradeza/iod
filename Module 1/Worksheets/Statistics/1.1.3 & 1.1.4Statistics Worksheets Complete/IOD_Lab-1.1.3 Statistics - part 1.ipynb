# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>
#
# # Statistics - Part 1

# %%
import numpy as np
import matplotlib.pyplot as plt
# get matplot to show charts inline
# %matplotlib inline

# %%
# frequency of some observations using pie chart
frequency = [15, 32, 12, 7]
frequency2 = [10, 20, 30, 40]

fig1, ax1 = plt.subplots()
explode = (0, 0, 0.5, 0)  # Set the third slice ('Data Scientists') to explode by 0.6

# Plot the first pie chart (frequency)
ax1.pie(frequency, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=240, radius=0.75)

ax1.pie(frequency2, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=360, radius=0.75, center=(0, -3), colors=['magenta', 'indigo', 'skyblue', 'lightsalmon'])

ax1.axis('equal')  # Equal aspect ratio ensures that the pie is drawn as a circle.

fig1.tight_layout()  # Tighter layout

plt.show()

# %%
# plot frequency of some observations using bar chart
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

# Create a bar plot of performance for each object
plt.xticks(???, ???)
plt.bar(???, ???)

# Use ylabel and title to label the y axis and provide a title
???
# Out:
#   Cell In[39], line 7
#     plt.xticks(???, ???)
#                ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# plot frequency of some observations using bar chart
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10, 8, 6, 4, 2, 1]

# Create a bar plot of performance for each object
plt.bar(y_pos, performance, align='edge', alpha=0.99, color='magenta')
plt.xticks(y_pos, objects)

# Label the y-axis and provide a title
plt.ylabel('Performance')
plt.title('Programming Language Performance')

plt.show()

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2023 Institute of Data
#
#
# ---
#
#
#
# ---
